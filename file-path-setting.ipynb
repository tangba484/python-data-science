# %%
import os
os.getcwd()
# Out:
# 'c:\\DA\\python-data-science'

# %%
from glob import glob

file_name = glob('data/*')[0]
file_name
# Out:
# 'data\\store_info'

# %%
import pandas as pd

pd.read_csv(file_name ,encoding='cp949')
# Out:
#     발생월 주야   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 0     1  주   9291   114  2506  10068     821
# 1     1  야   5838    74  1525   6139     534
# 2     2  주   8270    88  2105   9077     764
# 3     2  야   5566    77  1495   5943     560
# 4     3  주  10139    98  2553  11039    1057
# 5     3  야   5599    74  1436   5757     531
# 6     4  주  10862   109  2878  11699    1050
# 7     4  야   5438    88  1480   5459     572
# 8     5  주  11839   126  3176  12723    1163
# 9     5  야   5766   103  1576   6058     542
# 10    6  주  11232   119  2966  11972    1130
# 11    6  야   5458    98  1514   5462     575
# 12    7  주  10719   107  2697  11534    1063
# 13    7  야   5533    90  1496   5624     566
# 14    8  주  11393   137  2861  12633    1192
# 15    8  야   5607   104  1506   5698     611
# 16    9  주  10978   150  2905  11777    1109
# 17    9  야   5978   104  1653   5976     629
# 18   10  주  11410   119  3094  12079    1167
# 19   10  야   6310   106  1683   6318     642
# ...

# %%
# 여러파일 한번에 업로드

# %%
file_csv = glob('data/store_info/*.csv')
file_csv
# Out:
# ['data/store_info\\소상공인시장진흥공단_상가(상권)정보_강원_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_경기_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_경남_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_경북_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_광주_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_대구_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_대전_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_부산_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_서울_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_세종_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_울산_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_인천_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_전남_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_전북_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_제주_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_충남_202512.csv',
#  'data/store_info\\소상공인시장진흥공단_상가(상권)정보_충북_202512.csv']
